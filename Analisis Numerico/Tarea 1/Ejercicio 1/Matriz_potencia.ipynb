# %% [markdown]
# <b><font color= #000066  face="Comic Sans MS,arial">
#   <h1 ><i>Matriz potencia</i></h1>
#   <h5 ><i>Rodríguez César Axel </i></h5>
#   <h5><i>Rojas Bautista Alan Daniel .</i></h5>
#   </font>

# %% [markdown]
# Un programa que realice la potencia de una matriz, puede ser el siguiente:

# %%
def potencia_matriz(A, n):
    """
    Calcula la potencia n-ésima de una matriz A.

    Parámetros:
    A : La matriz a elevar.
    n : El exponente.

    Retorna:
     list: La matriz resultante de elevar A a la potencia n.
    """
    # Verificar que la matriz sea cuadrada
    assert len(A) == len(A[0]), "La matriz debe ser cuadrada."

    # Crear la matriz identidad del mismo tamaño que A
    identidad = [[1 if i == j else 0 for j in range(len(A))] for i in range(len(A))]

    # Si el exponente es 0, devolver la matriz identidad
    if n == 0:
        return identidad

    # Si el exponente es negativo, no se puede calcular con este método
    assert n > 0, "El exponente debe ser un entero no negativo."

    # Inicializar la matriz resultante como la matriz identidad
    resultado = identidad

    # Multiplicar la matriz por sí misma n veces
    for _ in range(n):
        resultado = multiplicar_matrices(resultado, A)

    return resultado

# Ejemplo de uso
A = [
    [1, 2],
    [3, 4]
]

n = 3

print("Matriz A:")
for fila in A:
    print(fila)

A_potencia = potencia_matriz(A, n)

print(f"\nMatriz A elevada a la potencia {n}:")
for fila in A_potencia:
    print(fila)
